# %% [markdown]
# # SEQ - VI Semana acadêmica de engenharia química
# **A Pluralidade da Engenharia: Criando possibilidades de carreira.**

# %% [markdown]
# ![seq.png](data:image/png;base64,...)

# %% [markdown]
# # PROJETO DE DATA SCIENCE: Conhecendo o ciclo CRISP-DM (Cross Industry Standard Process - Data Mining)
# Traduzindo de forma literal para o Português, pode ser entendido como **Processo padrão da indústria cruzada para mineração de dados**.

# %% [markdown]
# ![crisp.png](data:image/png;base64,...)

# %% [markdown]
# **Referência da imagem:** [Artigo no Medium](https://medium.com/@kvmoura/crisp-dm-79580b0d3ac4#id_token=eyJhbGciOiJSUzI1NiIsImtpZCI6IjA3NGI5MjhlZGY2NWE2ZjQ3MGM3MWIwYTI0N2JkMGY3YTRjOWNjYmMiLCJ0eXAiOiJKV1QifQ.....lXZNB1M5X_vVPfihWph3sVEWtgZ1MkmxWtWC-rj9C4tSKplw33I7STOm9-LhciYxz1higjAuUsXb-YfWbecQNLsyMSuFw-MQ4y1sACh0Wgd5_Nn_5s1zaVajYUxdx1N7MgtVTWF7QaqhPWYZjiIuNIUP2z401J0rdfuRLVyxvne9y4zTW03tLyLD9uAB-7fuKnzo2SKBYLChOPxhC2yDRsi1KIQaB8eG-auyq8c7zzgPdjT6YlZRBlfNiacVqfCoZHD00QrpcZABzQprk95_paR6LoMmBvRsq7L9IJumCc7mK8nJGUq_bOOb-asRNVWNUAkPMTf_1Px9nPt5oB_G4w)

# %% [markdown]
# # Entendimento do negócio:
#
# ---

# %% [markdown]
# **CONTEXTO FICTÍCIO:** A CAASF (Centro de abastecimento de água de São Francisco) é uma empresa pública que abastece algumas cidades do nordeste por meio do Rio São Francisco. Ela está tendo problemas com a qualidade da água fornecida à população, foi verificado que as vezes é utilizado quantidade indevida de materiais para o tratamento. Essa verificação é tida com alguns testes como por exemplo PH, turbidez, TOC (Total Organic Carbon), Sulfato, TDS (Total Dissolved solids), condutividade, entre outros...

# %% [markdown]
# **DESAFIO**: Você foi contratado como cientista de dados para fornecer um modelo que **prediz quais as melhores condições que as variáveis envolvidas tem que ter para fornecer uma água pótavel dentro dos padrões estabelecidos por lei.** Tudo isso para que não haja consumação de material ou energia no processo mais que o necessário. O seu diferencial como cientista de dados está no fato de você também ser engenheiro(a) químico(a), logo, também entenderá todo o processo de tratamento de ponta a ponta.
#
# Vale ressaltar que os ganhos desse projeto, além da otimização do processo como um todo como redução do gasto em materiais e energia, também haverá uma melhora na saúde da população, evitando que postos fiquem sobrecarregados por causa de doenças advindas de água mal tratada.

# %% [markdown]
# ## Mind Map Hipothesys:

# %% [markdown]
# - Construção de um mapa de hipóteses para auxiliar na seleção e coleta dos dados: [COGGLE](https://coggle.it/diagram/YuDrHbndxQl8quQV/t/-)

# %% [markdown]
# ![Predio_da_potabilidade_da_gua_smiley.png](data:image/png;base64,...)

# %% [markdown]
# # Entendimento dos dados
#
# ---

# %% [markdown]
# **Fonte:** [Kaggle](https://www.kaggle.com/datasets/adityakadiwal/water-potability)
#
# **Atributos:**
#
#
# 1. **PH:** O pH é um parâmetro importante na avaliação do equilíbrio ácido-base da água. É também o indicador da condição ácida ou alcalina do estado da água. A OMS recomendou o limite máximo permitido de pH de 6,5 a 8,5. Os intervalos de investigação atuais foram de 6,52 a 6,83, que estão na faixa dos padrões da OMS.
# 2. **Dureza:** A dureza é causada principalmente por sais de cálcio e magnésio. Esses sais são dissolvidos a partir de depósitos geológicos através dos quais a água viaja. O período de tempo em que a água está em contato com o material produtor de dureza ajuda a determinar quanta dureza existe na água bruta. A dureza foi originalmente definida como a capacidade da água de precipitar sabão causada por cálcio e magnésio.
# 3. **TDS:** A água tem a capacidade de dissolver uma ampla gama de minerais ou sais inorgânicos e alguns orgânicos, como potássio, cálcio, sódio, bicarbonatos, cloretos, magnésio, sulfatos, etc. Esses minerais produziram sabor indesejado e cor diluída na aparência da água. Este é o parâmetro importante para o uso da água. A água com alto valor de TDS indica que a água é altamente mineralizada. O limite desejável para TDS é de 500 mg/le o limite máximo é de 1000 mg/l prescrito para beber.
# 4. **Cloramina:** Cloro e cloramina são os principais desinfetantes usados ​​em sistemas públicos de água. As cloraminas são mais comumente formadas quando a amônia é adicionada ao cloro para tratar a água potável. Níveis de cloro de até 4 miligramas por litro (mg/L ou 4 partes por milhão (ppm)) são considerados seguros na água potável.
# 5. **Sulfatos:** Os sulfatos são substâncias naturais encontradas em minerais, solo e rochas. Eles estão presentes no ar ambiente, águas subterrâneas, plantas e alimentos. O principal uso comercial do sulfato é na indústria química. A concentração de sulfato na água do mar é de cerca de 2.700 miligramas por litro (mg/L). Varia de 3 a 30 mg/L na maioria dos suprimentos de água doce, embora concentrações muito mais altas (1000 mg/L) sejam encontradas em algumas localizações geográficas.
# 6. **Condutividade:** A água pura não é um bom condutor de corrente elétrica, mas um bom isolante. O aumento da concentração de íons aumenta a condutividade elétrica da água. Geralmente, a quantidade de sólidos dissolvidos na água determina a condutividade elétrica. A condutividade elétrica (EC) realmente mede o processo iônico de uma solução que lhe permite transmitir corrente. De acordo com os padrões da OMS, o valor EC não deve exceder 400 μS/cm.
# 7. **TOC:** O Carbono Orgânico Total (COT) nas águas de nascente vem de matéria orgânica natural em decomposição (NOM), bem como de fontes sintéticas. TOC é uma medida da quantidade total de carbono em compostos orgânicos em água pura. De acordo com a US EPA < 2 mg/L como TOC em água tratada/potável, e < 4 mg/Lit em água de fonte que é usada para tratamento.
# 8. **Trialometanos:** THMs são produtos químicos que podem ser encontrados em água tratada com cloro. A concentração de THMs na água potável varia de acordo com o nível de matéria orgânica na água, a quantidade de cloro necessária para tratar a água e a temperatura da água que está sendo tratada. Níveis de THM de até 80 ppm são considerados seguros na água potável.
# 9. **Turbidez:** A turbidez da água depende da quantidade de matéria sólida presente no estado suspenso. É uma medida das propriedades de emissão de luz da água e o teste é usado para indicar a qualidade da descarga de resíduos em relação à matéria coloidal. O valor médio de turbidez obtido para o Wondo Genet Campus (0,98 NTU) é inferior ao valor recomendado pela OMS de 5,00 NTU.
# 10. **Potabilidade (Variável Target):** Indica se a água é segura para consumo humano onde 1 significa Potável e 0 significa Não potável.

# %% [markdown]
# # 0.0 Imports
#
# ---

# %%
# Manipulação e visualização
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# Genérico
import warnings
warnings.filterwarnings("ignore")
import os
import pathlib

# Modelagem e Deploy
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics         as m
from scikitplot import metrics      as mt
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

import joblib

# %% [markdown]
# # 1.0 Data Loading

# %%
# Diretório raíz
PACKAGE_ROOT = pathlib.Path('.').resolve().parent

# Caminhos para os diretórios dos dados
DATADIR = os.path.join(PACKAGE_ROOT, 'data')
FILE_DATA = os.path.join(DATADIR, 'water_potability.csv')
MODEL_DIR = os.path.join(PACKAGE_ROOT,'model')

# %%
df = pd.read_csv(FILE_DATA)

# %% [markdown]
# # 2.0 Data Description
#
# ---

# %% [markdown]
# **Tarefas que devem ser realizadas nesse módulo:**
#
#
# 1. Visualizar o shape da base de dados
# 2. Renomear as colunas (Caso seja necessário)
# 3. Modificar o tipo de dado (Caso seja necessário)
# 4. Checar e completar os valores faltantes (Caso seja necessário)
# 5. Visualização estátistica sobre os dados

# %%
df2 = df.copy()

# %% [markdown]
# ## 2.1 Data Visualization

# %%
df2.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# ## 2.2 check NA

# %%
(df2.isna().sum()/len(df2))*100
# Out:
# ph                 14.987790
# Hardness            0.000000
# Solids              0.000000
# Chloramines         0.000000
# Sulfate            23.840049
# Conductivity        0.000000
# Organic_carbon      0.000000
# Trihalomethanes     4.945055
# Turbidity           0.000000
# Potability          0.000000
# dtype: float64

# %%
msno.matrix(df2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2.3 Fillout NA

# %% [markdown]
# ### 2.3.1 PH

# %% [markdown]
# **Entendendo as possíveis razões do PH ter valores faltantes:**

# %% [markdown]
# - Não foram feitas as análises.

# %% [markdown]
# **Para resolver o problema de dados faltantes para esse caso, podemos está adotando uma regra de negócio. Ex: Para água potável adotaremos o PH igual a 7 ou podemos entender a distrubuição e adotar pela média.**

# %%
# Analisando a distribuição de valores vazios.
df2[df2['ph'].isna()]['Potability'].value_counts()
# Out:
# 0    314
# 1    177
# Name: Potability, dtype: int64

# %%
sns.displot(df2.loc[df2['Potability']==1, 'ph'])

# %%
df2.loc[df2['Potability']==1, 'ph'].mean()
# Out:
# 7.0737832953812

# %%
# Adicionando o Valor 7 no PH para aqueles que foram adotados como água potável.
df2.loc[(df2['ph'].isna() == True) & (df2['Potability']==1), 'ph'] = 7

# %% [markdown]
# **DATA SCIENCE não é achismo!**
#
# ---
#
# **(Maneira errada) Utilizando o Feeling de um engenheiro químico para tratativa do processo:**
#
#
# No Caso da água não potável, analisando as outras variáveis envolvidas, podemos fazer uma estimativa do PH sendo alcalino ou mais ácido a partir da dureza do material.
# Partindo da premissa de que quanto menor a concentração de H+ maior será o PH, e sabendo que a dureza de uma água se refere à quantidade de bicarbonatos, carbonatos, sulfatos ou cloretos de cálcio e magnésio dissolvidos nela, podemos entender que, geralmente, águas com alta dureza são mais alcalinas. Nesse caso, podemos olhar a distribuição do índice de dureza e selecionar as condições para a água não potável ter um PH igual a 4 ou 9 para baixa e alta dureza, respectivamente (Valores adotados arbitrariamente).

# %%
# Copiando o DataFrame
df_achismo = df2.copy()

# %%
# Distribuição da dureza e do PH
plt.figure(figsize=[5,5])
sns.displot(df_achismo['Hardness']);

sns.displot(df_achismo['ph']);

# %%
# Adicionando o Valor 4 no PH para aquelas amostras com dureza menor ou igual a 200.
df_achismo.loc[(df_achismo['ph'].isna() == True) & (df_achismo['Hardness']<=200), 'ph'] = 4

# Adicionando o Valor 9 no PH para aquelas amostras com dureza maior que 200.
df_achismo.loc[(df_achismo['ph'].isna() == True) & (df_achismo['Hardness']>200), 'ph'] = 9

# %%
# Verificação da curva de distribuição
sns.displot(df_achismo['ph'])

# %% [markdown]
# Um erro grave ao fazer os devidos tratamentos nos dados no momento de substituir dados faltantes é modificar o formato da sua distrubuição.

# %% [markdown]
# **Uma outra solução seria entender se há uma distribuição normal envolvida no PH e substituir os valores faltantes pela média de acordo com a dureza.**

# %%
# Distribuição do ph
sns.displot(df2['ph'])

# %%
df2['ph'] = df2['ph'].fillna(df2['ph'].mean())

# %% [markdown]
# ### 2.3.2 Sulfate

# %% [markdown]
# **Para entender como devemos substituir os valores faltantes, já que removê-los não é uma boa escolha, temos que entender a distribuição dos valores faltantes e como ocorre a distribuição da variável para água potável e não potável.**

# %%
# Analisando a distribuição da qualidade da água em relação aos valores vazios.
df2[df2['Sulfate'].isna()]['Potability'].value_counts()
# Out:
# 0    488
# 1    293
# Name: Potability, dtype: int64

# %%
# Distribuição da variável Sulfate quando a potabilidade é igual a 1.
sns.displot(df2.loc[df2['Potability']==1]['Sulfate'])

# %%
# Distribuição da variável Sulfate quando a potabilidade é igual a 0.
sns.displot(df2.loc[df2['Potability']==0]['Sulfate'])

# %%
df2.loc[df2['Potability']==0]['Sulfate'].mean()
# Out:
# 334.5642895786881

# %% [markdown]
# Como podemos perceber, existe uma distribuição próxima da normal para ambos os casos. Sendo assim, podemos substituir os valores faltantes pela respectiva média de cada.

# %%
# média de Sulfate
media_sulfate = df2['Sulfate'].mean()
# substituição dos valores vazios
df2['Sulfate'] = df2['Sulfate'].fillna(media_sulfate)

# %% [markdown]
# ### 2.3.3 Trihalomethanes

# %% [markdown]
# Da mesmo forma que os itens anteriores, teremos que entender como devemos substituir os valores faltantes ou se faz mais sentido removê-los uma vez que representam apenas **4%** do nosso Dataset.

# %%
#Analisando a distribuição da qualidade da água em relação aos valores vazios.
df2[df2['Trihalomethanes'].isna()]['Potability'].value_counts()
# Out:
# 0    107
# 1     55
# Name: Potability, dtype: int64

# %%
# Distribuição da variável Sulfate quando a potabilidade é igual a 1.
sns.displot(df2.loc[df2['Potability']==1]['Trihalomethanes'])

# %%
# Distribuição da variável Sulfate quando a potabilidade é igual a 1.
sns.displot(df2.loc[df2['Potability']==0]['Trihalomethanes'])

# %% [markdown]
# Como podemos perceber, existe uma distribuição normal para ambos os casos. Sendo assim, podemos substituir os valores faltantes pela respectiva média de cada da mesma forma que fizemos para a variável Sulfate.

# %%
# média de Sulfate
media_thm = df2['Trihalomethanes'].mean()
# substituição dos valores vazios
df2['Trihalomethanes'] = df2['Trihalomethanes'].fillna(media_thm)

# %% [markdown]
# ## 2.4 Descriptive Statistical

# %%
df2.describe().T
# Out:
#                   count          mean          std         min           25%  \
# ph               3276.0      7.075966     1.470069    0.000000      6.277673
# Hardness         3276.0    196.369496    32.879761   47.432000    176.850538
# Solids           3276.0  22014.092526  8768.570828  320.942611  15666.690297
# Chloramines      3276.0      7.122277     1.583085    0.352000      6.127421
# Sulfate          3276.0    333.775777    36.142612  129.000000    317.094638
# Conductivity     3276.0    426.205111    80.824064  181.483754    365.734414
# Organic_carbon   3276.0     14.284970     3.308162    2.200000     12.065801
# Trihalomethanes  3276.0     66.396293    15.769881    0.738000     56.647656
# Turbidity        3276.0      3.966786     0.780382    1.450000      3.439711
# Potability       3276.0      0.390110     0.487849    0.000000      0.000000
#
#                           50%           75%           max
# ph                   7.075966      7.870050     14.000000
# ...

# %% [markdown]
# # 3.0 Feature Engineerging

# %% [markdown]
# **Essa etapa precisaria de um estudo mais aprofundado sobre o negócio e também seria necessário verificar se não haveria mais atributos disponíveis caso fosse um case real.**

# %% [markdown]
# # 4.0 Exploratory Data Analysis

# %%
# Copy data frame:
df4 = df2.copy()

# %% [markdown]
# ## 4.1 Análise Univariada

# %% [markdown]
# ### 4.1.1 Target Variable

# %%
# Value Counts Normalize:
df4['Potability'].value_counts(normalize= True)
# Out:
# 0    0.60989
# 1    0.39011
# Name: Potability, dtype: float64

# %%
map_pot = {1: 'YES', 0: 'NO'}
df4['Potability_cat'] = df4['Potability'].map(map_pot)

# %%
# Analise gráfica
df4['Potability_cat'].value_counts(normalize=True).plot.pie(autopct='%.0f%%');

# %% [markdown]
# ### 4.1.2 Numerical Variables

# %%
df4.hist(figsize=[15,10] );

# %% [markdown]
# ## 4.2 Análise Bivariada:

# %% [markdown]
# Essa etapa pode ser processada para responder algumas hipóteses planejadas no inicio do projeto.
#
# No nosso caso, não estaremos abordando essas hipóteses, mas a fim de conhecimento uma hipótese seria gerada para criar insights ou desafiar alguma crença. Por exemplo: **Água com PH abaixo de 6 tende a não ser potável**.

# %%
# Análise Gráfica

sns.pairplot(df4, hue='Potability', markers=["o", "s"],corner=True)

# %% [markdown]
# Análise de correlação:

# %%
correlation = df4.corr(method= 'pearson')
plt.figure(figsize=[10,10])
sns.heatmap(correlation, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# É observado que as features que temos para a modelagem do nosso modelo tem pouca correlação com a variável target. Sendo assim, no outro ciclo precisaríamos focar na etapa de Feature Engineer e coleta de mais dados.

# %% [markdown]
# # 5.0 Data Preparation

# %% [markdown]
# Como nesse DataSet consta apenas atributos numéricos, e todos tem uma distribuição que se aproxima da normal, podemos utiliza aqui um método de padronização para deixar todos na mesma escala.

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1 Divisão de treino e teste

# %% [markdown]
# ![1_AOwsTgJnh_b_oLIAaAn8Bg.png](data:image/png;base64,...)

# %%
features_col = df5.columns[:9].tolist()
features = df5.drop(columns=['Potability','Potability_cat'])
target = df5['Potability_cat']

# %%
x_train, x_test, y_train, y_test =train_test_split(features, target,
                                                    random_state = 42, test_size = 0.20)

# %% [markdown]
# ## 5.2 Escala

# %% [markdown]
# ![padronizacao.png](data:image/png;base64,...)

# %% [markdown]
# ![1_9A-rlaYWkOnWu-JiftKDQA.png](data:image/png;base64,...)
#
# ![1_jQ3jl2lecfgjIQT94mAFpw.png](data:image/png;base64,...)
#
# ![1_iYwthw50xJ1vtovHTkGtbg.png](data:image/png;base64,...)![1_1nBw0cKMR3K3zHsMisckfA.png](data:image/png;base64,...)

# %% [markdown]
# # 6.0 Training Model

# %%
# Padronização
sc = StandardScaler()

# Modelos
# Regressão Logística
lr = LogisticRegression()

# Modelo Random Forest (Conjunto de árvores de decisão)
rf = RandomForestClassifier()

# %%
pipe_lr = make_pipeline(sc, lr)
pipe_rf = make_pipeline(sc,rf)

# %%
# Treinando o pipeline do modelo de Regressão logística
pipe_lr.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
pipe_rf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %% [markdown]
# # 7.0 Model Selection

# %% [markdown]
# ## 7.1 Avaliação do modelo

# %%
# Lista dos modelos
list_model = [pipe_lr, pipe_rf]

# %%
for i in list_model:
  print(f'Modelo: {i}')
  # prediction 
  predict_model = i.predict( x_test )
  # Accuracy
  acc_nn = m.accuracy_score( 
                  y_test, 
                  predict_model
                  )
  print('Accuracy: {}'.format(acc_nn))
  # Balanced accury Score

  b_acc_nn = m.balanced_accuracy_score(
                          y_test,
                          predict_model
                              )
  print('Balanced Accuracy: {}'.format(b_acc_nn))

  # Kappa Metrics
  kappa_nn = m.cohen_kappa_score(
                              y_test,
                              predict_model
                                  )
  print('Kappa Score: {}'.format(kappa_nn))

  # Classification report
  print(m.classification_report(y_test, predict_model))

  # new confusion matrix
  cm = m.confusion_matrix(y_test, predict_model, labels = i.classes_)
  disp = m.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels = i.classes_)
  disp.plot();


  # Confusion Matrix
 # mt.plot_confusion_matrix(
 #                       y_test,
 #                       predict_model, 
 #                       normalize=False, 
 #                       figsize=(12,12)
 #                       )
  print('-'*30)
# Out:
# Modelo: Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])
# Accuracy: 0.6280487804878049
# Balanced Accuracy: 0.5
# Kappa Score: 0.0
#               precision    recall  f1-score   support
#
#           NO       0.63      1.00      0.77       412
#          YES       0.00      0.00      0.00       244
#
#     accuracy                           0.63       656
#    macro avg       0.31      0.50      0.39       656
# weighted avg       0.39      0.63      0.48       656
#
# ------------------------------
# Modelo: Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])
# Accuracy: 0.7301829268292683
# Balanced Accuracy: 0.6748965462358746
# Kappa Score: 0.37721518987341773
#               precision    recall  f1-score   support
#
#           NO       0.74      0.89      0.81       412
#          YES       0.71      0.46      0.56       244
#
# ...

# %% [markdown]
# # 8.0 Deployment

# %%
# Salvando o modelo
FILE_MODEL = os.path.join(MODEL_DIR,'clf_randomforest.joblib')
joblib.dump(pipe_rf,FILE_MODEL)
# Out:
# ['D:\\Valorizando_dados\\Projetos\\water_quality\\model\\clf_randomforest.joblib']

# %%
# Salvando o outro modelo
FILE_MODEL = os.path.join(MODEL_DIR,'clf_logisticregression.joblib')
joblib.dump(pipe_lr,FILE_MODEL)
# Out:
# ['D:\\Valorizando_dados\\Projetos\\water_quality\\model\\clf_logisticregression.joblib']

# %%
x_test[:1]
# Out:
#             ph    Hardness       Solids  Chloramines     Sulfate  \
# 2947  7.075966  183.521107  20461.25271     7.333212  333.119476
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 2947    356.369022       20.179029        67.019903   4.886634

# %%
y_test[:1]
# Out:
# 2947    NO
# Name: Potability_cat, dtype: object

# %%
x = pipe_rf.predict_proba(x_test[:1])

# %%
x[0][0]
# Out:
# 0.96
